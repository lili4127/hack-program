# %% [markdown]
# ## Python challenges
#
# This notebook includes a series of challenges to test your Python coding skills. If you get stuck, try googling for answers. If you don't understand *why* a particular answer works, try searching for the answer to that question. Revisit old tutorials from this class as needed, and finally, turn to the course chatroom for help. Best of luck.

# %%
# required software
# conda install numpy pandas toyplot requests -c conda-forge

# %%
import requests
import numpy as np
import pandas as pd
import toyplot

# %% [markdown]
# ### Challenge 1:
# Execute the code cell below to see an example of how it works.
# Use markdown in the cell after the code-block to describe the function `random_words_api`. Try to be descriptive about what each step of code in this function does, and why it works.

# %%
def random_words_api(nwords=10):
    "no docstring"
    URL = "https://random-word-api.herokuapp.com/word"
    response = requests.get(url=URL, params={"number": nwords})
    return response.json()

# demonstration
random_words_api(5)
# Out:
# ['subtopias', 'balsam', 'estrangements', 'aquatint', 'pearlers']

# %% [markdown]
# **Description:**
# random_words_api returns a list of n random words (default is 10) generated through the API at the URL. It does this by sending a get command to the web address URL returning a Response Class object with n random words which is parsed as a dictionary and returned through the json function.

# %% [markdown]
# ### Challenge 2:
# Use the `random_words_api` function to get 50 random words and store the result as a variable. Write a function that takes the list of words as input and returns a dictionary with the longest word as the key and the length of the longest word as a value. If there is a tie in the length of words then have it return additional words as keys with their lengths as values.

# %%
l = random_words_api(50)

def longest_words(l):
    lsorted = sorted(l,key=len)
    final = {}
    for word in lsorted:
        if len(word) == len(lsorted[-1]):
            final[word] = len(word)
    return final
print(longest_words(l))
# Out:
# {'defibrillations': 15, 'antiliberalisms': 15}

# %% [markdown]
# ### Challenge 3:
# Write a function to take the list of words as input and trim all words to be at most 5 characters in length, and return as a list.

# %%
def trim_words(l):
    trimmed = []
    for word in l:
        trimmed.append(word[:5])
    return trimmed

print(trim_words(l))
# Out:
# ['confe', 'scale', 'cushi', 'short', 'iceca', 'pento', 'bante', 'polym', 'contr', 'jogge', 'mitoc', 'defib', 'metro', 'heirl', 'amort', 'overf', 'antil', 'dogge', 'smoke', 'preco', 'super', 'squal', 'genog', 'exemp', 'sates', 'foehn', 'immun', 'puddl', 'eutha', 'armil', 'blund', 'emuls', 'hardb', 'switc', 'cross', 'lacta', 'kotos', 'ausfo', 'derri', 'belly', 'bousi', 'maywe', 'slime', 'cutaw', 'conta', 'hon', 'oblit', 'nonre', 'schoo', 'antip']

# %% [markdown]
# ### Challenge 4:
# Write a function to take a list of words as input and to count the occurrence of all letters in every word and return as a dictionary mapping letters to integers., e.g., {'a': 10, 'b': 3, 'c': 5, ...}.

# %%
def count_occurence(l):
    alphabet = {'a' : 0, 'b' : 0, 'c' : 0, 'd' : 0, 'e' : 0, 'f' : 0, 'g' : 0, 
                'h' : 0, 'i' : 0, 'j' : 0, 'k' : 0, 'l' : 0, 'm' : 0, 'n' : 0, 
                'o' : 0, 'p' : 0, 'q' : 0, 'r' : 0, 's' : 0, 't' : 0, 'u' : 0, 
                'v' : 0, 'w' : 0, 'x' : 0, 'y' : 0, 'z' : 0}
    for word in l:
        for letter in word:
            if letter.lower() in alphabet:
                alphabet[letter.lower()] += 1
    return alphabet

print(count_occurence(l))
# Out:
# {'a': 31, 'b': 9, 'c': 17, 'd': 15, 'e': 52, 'f': 6, 'g': 12, 'h': 12, 'i': 33, 'j': 1, 'k': 3, 'l': 28, 'm': 17, 'n': 30, 'o': 41, 'p': 9, 'q': 1, 'r': 38, 's': 46, 't': 26, 'u': 13, 'v': 2, 'w': 4, 'x': 1, 'y': 8, 'z': 3}

# %% [markdown]
# ### Challenge 5:
# Use [toyplot](https://toyplot.readthedocs.io/en/stable/tutorial.html) to create a barplot of the occurrences of each letter in your dictionary from the previous challenge. This will represent a histogram of the letters. Play with the size and color of the figure to try to make it look nice.

# %%
canvas = toyplot.Canvas(width=500, height=300)
axes = canvas.cartesian(label="Letter Occurence", xlabel="Letter", ylabel="Count",
                        ymax = max(list(count_occurence(l).values())))
heights = list(count_occurence(l).values())
labels = list(count_occurence(l).keys())

#hover over a bar to see what letter it corresponds to
mark = axes.bars(heights, color='blue',title=labels)
# Out:
# <div class="toyplot" id="t8b1aa2c842a44442ba36a10fda62bee9" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t1d309c7b8d144a1dbada1860da69a11d" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 300.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t1afd50a4cfe14be6accd6a38ee4d7338"><clipPath id="t512e37caf6be4e778bb337cdd198f0c7"><rect height="220.0" width="420.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t512e37caf6be4e778bb337cdd198f0c7)"><g class="toyplot-mark-BarMagnitudes" id="t0ca5f37e645840e0a3ff65442060b6aa" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><g class="toyplot-Series"><rect class="toyplot-Datum" height="103.33333333333334" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="13.114754098360656" x="50.0" y="146.66666666666666"><title>a</title></rect><rect class="toyplot-Datum" height="30.0" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="13.11475409836067" x="63.114754098360656" y="220.0"><title>b</title></rect><rect class="toyplot-Datum" height="56.666666666666686" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="13.114754098360635" x="76.22950819672133" y="193.33333333333331"><title>c</title></rect><rect class="toyplot-Datum" height="50.0" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="13.114754098360663" x="89.34426229508196" y="200.0"><title>d</title></rect><rect class="toyplot-Datum" height="173.33333333333334" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="13.114754098360663" x="102.45901639344262" y="76.66666666666666"><title>e</title></rect><rect class="toyplot-Datum" height="20.0" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="13.114754098360635" x="115.57377049180329" y="230.0"><title>f</title></rect><rect class="toyplot-Datum" height="40.0" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="13.114754098360663" x="128.68852459016392" y="210.0"><title>g</title></rect><rect class="toyplot-Datum" height="40.0" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="13.114754098360663" x="141.80327868852459" y="210.0"><title>h</title></rect><rect class="toyplot-Datum" height="110.0" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="13.114754098360635" x="154.91803278688525" y="140.0"><title>i</title></rect><rect class="toyplot-Datum" height="3.333333333333343" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="13.114754098360692" x="168.03278688524588" y="246.66666666666666"><title>j</title></rect><rect class="toyplot-Datum" height="10.0" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="13.114754098360663" x="181.14754098360658" y="240.0"><title>k</title></rect><rect class="toyplot-Datum" height="93.33333333333331" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stro ...

# %% [markdown]
# ### Challenge 6:
# Using numpy create a new variable called `arr` with 1000 random samples from a normal distribution. Use the numpy `.histogram` function to bin these values into 20 bins, and then plot the histogram using a barplot from toyplot. Color the bars of the histogram orange.

# %%
arr = np.random.normal(size=1000)
canvas = toyplot.Canvas(width=300, height=300)
axes = canvas.cartesian()
bars = axes.bars(np.histogram(arr, 20),color='orange')
# Out:
# <div class="toyplot" id="tfdca8a892fd34e0198fb5f79d55cf158" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t0583ef5b89e646f4adae9572c4c211b5" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 300.0 300.0" width="300.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="taed2693e12ba461c8f6dcc157c3ef328"><clipPath id="t1d2d792a7c614e45bab14dea32dab3c3"><rect height="220.0" width="220.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t1d2d792a7c614e45bab14dea32dab3c3)"><g class="toyplot-mark-BarMagnitudes" id="te7df8c8721b549a5ac4cecc65154363b" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><g class="toyplot-Series"><rect class="toyplot-Datum" height="9.375" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="10.0" x="50.0" y="240.625"></rect><rect class="toyplot-Datum" height="14.0625" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="10.0" x="60.0" y="235.9375"></rect><rect class="toyplot-Datum" height="21.875" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="10.0" x="70.0" y="228.125"></rect><rect class="toyplot-Datum" height="35.9375" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="10.0" x="80.0" y="214.0625"></rect><rect class="toyplot-Datum" height="48.4375" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="10.0" x="90.0" y="201.5625"></rect><rect class="toyplot-Datum" height="87.5" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="10.0" x="100.0" y="162.5"></rect><rect class="toyplot-Datum" height="126.5625" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="10.0" x="110.0" y="123.4375"></rect><rect class="toyplot-Datum" height="159.375" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="10.0" x="120.0" y="90.625"></rect><rect class="toyplot-Datum" height="200.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="10.0" x="130.0" y="50.0"></rect><rect class="toyplot-Datum" height="189.0625" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="10.0" x="140.0" y="60.9375"></rect><rect class="toyplot-Datum" height="184.375" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="10.0" x="150.0" y="65.625"></rect><rect class="toyplot-Datum" height="165.625" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="10.0" x="160.0" y="84.375"></rect><rect class="toyplot-Datum" height="107.8125" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="9.999999999999972" x="170.0" y="142.1875"></rect><rect class="toyplot-Datum" height="92.1875" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="10.000000000000028"  ...

# %% [markdown]
# ### Challenge 7:
# Write a `while` statement to continue running code in a loop until a condition is met, and then call `break` to end the loop. Inside of the loop, randomly draw a single value from a uniform distribution between 0 and 100. If the value is less than 25 and greater than 22 then break the loop, otherwise, continue the loop until a value meeting this condition is sampled. Use a variable to keep track of how many iterations of the loop are run, and print this value after calling `break`.

# %%
counter = 0
while(1):
    value = np.random.uniform(0,100)
    if value < 25 and value > 22:
        break
    else:
        counter += 1
print(counter)
# Out:
# 9

# %% [markdown]
# ### Challenge 8:
# Use pandas to load a CSV file from https://eaton-lab.org/data/iris-data-dirty.csv and save as a dataframe. Add custom names to the columns in the dataframe, based on the type of values in them (e.g., numeric versus strings). You can come up with any column names you want for these.

# %%
df = pd.read_csv("https://eaton-lab.org/data/iris-data-dirty.csv")
df.columns = ['1:float','2:float','3:float','4:float','5:string']
df
# Out:
#      1:float  2:float  3:float  4:float        5:string
# 0        4.9      3.0      1.4      0.2     Iris-setosa
# 1        4.7      3.2      1.3      0.2     Iris-setosa
# 2        4.6      3.1      1.5      0.2     Iris-setosa
# 3        5.0      3.6      1.4      0.2     Iris-setosa
# 4        5.4      3.9      1.7      0.4     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 144      6.7      3.0      5.2      2.3  Iris-virginica
# 145      6.3      2.5      5.0      1.9  Iris-virginica
# 146      6.5      3.0      5.2      2.0  Iris-virginica
# 147      6.2      3.4      5.4      2.3  Iris-virginica
# 148      5.9      3.0      5.1      1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Challenge 9:
# Calculate the mean value of the data in the left-most column for all data where the right-most column matches the value "Iris-setosa".

# %%
left = list(df['1:float'])
right = list(df['5:string'])
total = []

for i in range(len(left)):
    if right[i] == "Iris-setosa":
        total.append(left[i])
print(sum(total)/len(total))
# Out:
# 5.008333333333333

# %% [markdown]
# ### Challenge 10:
# Create a copy of your iris data dataframe and name it `df2`. Sort the rows of this dataframe based on the values in the first (leftmost) column so that the lowest values are first, and the highest values at the bottom. After sorting, reset the index of the dataframe so that the index is once again ordered. Once you get this to work, try to rewrite it in a simpler form by chaining multiple function calls together to accomplish the goal in one line, by calling code that looks a bit like this, but with the correct function calls: `df.function().function().function()`

# %%
df2 = df.copy().sort_values(by=['1:float']).reset_index()
df2
# Out:
#      index  1:float  2:float  3:float  4:float        5:string
# 0       12      4.3      3.0      1.1      0.1     Iris-setosa
# 1       41      4.4      3.2      1.3      0.2     Iris-setosa
# 2       37      4.4      3.0      1.3      0.2     Iris-setosa
# 3        7      4.4      2.9      1.4      0.2     Iris-setosa
# 4       40      4.5      2.3      1.3      0.3     Iris-setosa
# ..     ...      ...      ...      ...      ...             ...
# 144    117      7.7      2.6      6.9      2.3  Iris-virginica
# 145    116      7.7      3.8      6.7      2.2  Iris-virginica
# 146    121      7.7      2.8      6.7      2.0  Iris-virginica
# 147    134      7.7      3.0      6.1      2.3  Iris-virginica
# 148    130      7.9      3.8      6.4      2.0  Iris-virginica
#
# [149 rows x 6 columns]

# %% [markdown]
# ### Challenge 11:
# Write a function that uses string formatting (curly braces) to create a [mad lib](https://en.wikipedia.org/wiki/Mad_Libs) containing at least 4 words that will be filled in. The returned object of your function should be a string where the missing words are filled by randomly sampled words from the `random_words_api()` function. The sentence or paragraph of your mad lib can be anything you wish, be creative.

# %%
def madlib(cheese1,cheese2,cheese3,cheese4):
    return f"""\n Customer: I'd like to buy some {cheese1}.\n 
    Wenslydale: I'm sorry sir we're all out of {cheese1}.\n
    Customer: Tish tish. No matter. Well, stout yeoman, four ounces of {cheese2}, if you please.\n 
    Wenslydale: Ah! It's beeeen on order, sir, for two weeks. Was expecting it this morning.\n 
    Customer: 'T's Not my lucky day, is it? Any {cheese3}, per chance?\n
    Wenslydale: Normally, sir, yes. Today the van broke down.\n
    Customer: {cheese4}, perhaps?\n
    Wenslydale: Yessir. It's..ah,.....it's a bit runny...\n
    Customer: Oh, I like it runny.\n
    Wenslydale: Well,.. It's very runny, actually, sir.\n
    Customer: No matter. Fetch hither the {cheese4}!\n
    Wenslydale: I...think it's a bit runnier than you'll like it, sir.\n
    Customer: I don't care how fucking runny it is. Hand it over with all speed.\n
    Wenslydale: Oooooooooohhh........! (pause)\n
    Customer: What now?\n
    Wenslydale: The cat's eaten it."""
    
r = random_words_api(4)
print(madlib(r[0],r[1],r[2],r[3]))
# Out:
#  Customer: I'd like to buy some caddisflies.
#
#     Wenslydale: I'm sorry sir we're all out of caddisflies.
#
#     Customer: Tish tish. No matter. Well, stout yeoman, four ounces of wheeples, if you please.
#
#     Wenslydale: Ah! It's beeeen on order, sir, for two weeks. Was expecting it this morning.
#
#     Customer: 'T's Not my lucky day, is it? Any paramatta, per chance?
#
#     Wenslydale: Normally, sir, yes. Today the van broke down.
#
#     Customer: pestier, perhaps?
#
#     Wenslydale: Yessir. It's..ah,.....it's a bit runny...
#
#     Customer: Oh, I like it runny.
#
#     Wenslydale: Well,.. It's very runny, actually, sir.
#
#     Customer: No matter. Fetch hither the pestier!
#
#     Wenslydale: I...think it's a bit runnier than you'll like it, sir.
#
#     Customer: I don't care how fucking runny it is. Hand it over with all speed.
#
#     Wenslydale: Oooooooooohhh........! (pause)
#
#     Customer: What now?
#
#     Wenslydale: The cat's eaten it.

# %% [markdown]
# <div class="alert alert-success">
# After completing all challenges in this notebook, save and download the .ipynb file to your computer. Move the file to your hack-program repo and put it in a folder called notebooks. Add/stage this file and folder and commit the change, and push to GitHub. The assignment is due by end of day on 3/7/2021.
# </div>
